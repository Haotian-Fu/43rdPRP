# %%
import torch

# %%
# Customize parameters
env_id = 'simple_spread'
model_name = 'maac'
run_num = 1
run_time = 'run' + str(run_num)

# Directory name
dir = 'models/' + env_id + '/' + model_name + '/' + run_time + '/model.pt'

# Load category and color encodings
cat_dict = torch.load(dir)
for k, v in cat_dict.items():  # k 参数名 v 对应参数值
    print(k, v)
# Out:
# init_dict {'gamma': 0.99, 'tau': 0.001, 'pi_lr': 0.001, 'q_lr': 0.001, 'reward_scale': 100.0, 'pol_hidden_dim': 128, 'critic_hidden_dim': 128, 'attend_heads': 4, 'agent_init_params': [{'num_in_pol': 18, 'num_out_pol': 5}, {'num_in_pol': 18, 'num_out_pol': 5}, {'num_in_pol': 18, 'num_out_pol': 5}], 'sa_size': [(18, 5), (18, 5), (18, 5)]}
# agent_params [{'policy': OrderedDict([('in_fn.running_mean', tensor([-0.0153, -0.0809, -0.0460,  0.0252, -0.0714,  0.0114,  0.0927, -0.1368,
#          0.0380, -0.0427,  0.3271,  0.0199,  0.1371, -0.1818,  0.0000,  0.0000,
#          0.0000,  0.0000])), ('in_fn.running_var', tensor([0.1998, 0.3403, 0.5282, 0.7624, 0.9276, 1.1415, 0.7932, 0.8853, 0.8296,
#         1.0057, 1.0499, 1.1418, 1.0819, 1.0386, 0.0018, 0.0018, 0.0018, 0.0018])), ('in_fn.num_batches_tracked', tensor(60)), ('fc1.weight', tensor([[ 0.1312, -0.1224, -0.0926,  ..., -0.0212,  0.0342, -0.0009],
#         [ 0.1854,  0.1121, -0.0469,  ..., -0.2148, -0.2241, -0.1137],
# ...
